# %%
# %run test_attention.py --task A --weights_path bests/Super_class/v3_82_mixed/best_model_v3_mixed.pth --batch_size 8 --area_attn_heads 16 --area_attn_split_factor 8 --num_relan_blocks 2 2 4 2 --backbone_channels 32 --stage_channels 128 256 512 1024 --stage_hidden_channels 64 128 256 512 --relan_branches 4 --cbam_reduction 16 --cbam_kernel_size 7 --activation silu --num_workers 0 --device auto
# Out:
# ...
# Successfully imported from utils.data_loader
# Successfully imported DynamicRELANClassifier and RELANBlock from models.attention_is_all_you_need
# PyTorch version: 2.6.0+cu126
# CUDA available: True, Version: 12.6
# Device name: NVIDIA GeForce RTX 3060 Ti
# Looking for data in: c:\Users\Wangzy\Desktop\9444\data
#
# ----- Mode: EVALUATION (Weights found: bests/Super_class/v3_82_mixed/best_model_v3_mixed.pth) -----
#
# ----- Determining Setup for Task A -----
# Using num_classes = 4 (from data_loader import - superclass)
# Using generic superclass names: ['Superclass_0', 'Superclass_1', 'Superclass_2', 'Superclass_3']
# Using device: cuda
#
# ----- Creating DataLoader for Task A -----
# Successfully created DataLoader (test_loader (from create_data_loaders2)).
#
# ----- Instantiating Model Architecture -----
#  Stage 0: Using attention pattern: ('cbam', 'area', 'cbam')
#  Stage 1: Using attention pattern: ('area', 'cbam', 'area')
# ...

# %%
# %run test_attention.py --task A --weights_path bests/Super_class/v4_areas/best_model_v4_areas.pth --batch_size 8 --area_attn_heads 16 --area_attn_split_factor 8 --num_relan_blocks 2 2 4 2 --backbone_channels 32 --stage_channels 128 256 512 1024 --stage_hidden_channels 64 128 256 512 --relan_branches 4 --cbam_reduction 16 --cbam_kernel_size 7 --activation silu --num_workers 0 --device auto
# Out:
# ...
# Successfully imported from utils.data_loader
# Successfully imported DynamicRELANClassifier and RELANBlock from models.attention_is_all_you_need
# PyTorch version: 2.6.0+cu126
# CUDA available: True, Version: 12.6
# Device name: NVIDIA GeForce RTX 3060 Ti
# Looking for data in: c:\Users\Wangzy\Desktop\9444\data
#
# ----- Mode: EVALUATION (Weights found: bests/Super_class/v4_areas/best_model_v4_areas.pth) -----
#
# ----- Determining Setup for Task A -----
# Using num_classes = 4 (from data_loader import - superclass)
# Using generic superclass names: ['Superclass_0', 'Superclass_1', 'Superclass_2', 'Superclass_3']
# Using device: cuda
#
# ----- Creating DataLoader for Task A -----
# Successfully created DataLoader (test_loader (from create_data_loaders2)).
#
# ----- Instantiating Model Architecture -----
#  Stage 0: Using attention pattern: ('area', 'area', 'area')
#  Stage 1: Using attention pattern: ('area', 'area', 'area')
# ...

# %%
# %run test_attention.py --task A --weights_path bests/Super_class/v5_85_mixed_adamw/best_model_v5.pth --batch_size 8 --area_attn_heads 16 --area_attn_split_factor 8 --num_relan_blocks 2 2 4 2 --backbone_channels 64 --stage_channels 128 256 512 1024 --stage_hidden_channels 64 128 256 512 --relan_branches 4 --cbam_reduction 16 --cbam_kernel_size 7 --activation silu --num_workers 0 --device auto
# Out:
# ...
# Successfully imported from utils.data_loader
# Successfully imported DynamicRELANClassifier and RELANBlock from models.attention_is_all_you_need
# PyTorch version: 2.6.0+cu126
# CUDA available: True, Version: 12.6
# Device name: NVIDIA GeForce RTX 3060 Ti
# Looking for data in: c:\Users\Wangzy\Desktop\9444\data
#
# ----- Mode: EVALUATION (Weights found: bests/Super_class/v5_85_mixed_adamw/best_model_v5.pth) -----
#
# ----- Determining Setup for Task A -----
# Using num_classes = 4 (from data_loader import - superclass)
# Using generic superclass names: ['Superclass_0', 'Superclass_1', 'Superclass_2', 'Superclass_3']
# Using device: cuda
#
# ----- Creating DataLoader for Task A -----
# Successfully created DataLoader (test_loader (from create_data_loaders2)).
#
# ----- Instantiating Model Architecture -----
#  Stage 0: Using attention pattern: ('cbam', 'area', 'cbam')
#  Stage 1: Using attention pattern: ('area', 'cbam', 'area')
# ...

# %%
# %run test_attention.py --task A --weights_path bests/Super_class/v7_40_mixed_sgd_controlled/best_model_sgd.pth --batch_size 8 --area_attn_heads 16 --area_attn_split_factor 8 --num_relan_blocks 2 2 4 2 --backbone_channels 64 --stage_channels 128 256 512 1024 --stage_hidden_channels 64 128 256 512 --relan_branches 4 --cbam_reduction 16 --cbam_kernel_size 7 --activation silu --num_workers 0 --device auto
# Out:
# ...
# Successfully imported from utils.data_loader
# Successfully imported DynamicRELANClassifier and RELANBlock from models.attention_is_all_you_need
# PyTorch version: 2.6.0+cu126
# CUDA available: True, Version: 12.6
# Device name: NVIDIA GeForce RTX 3060 Ti
# Looking for data in: c:\Users\Wangzy\Desktop\9444\data
#
# ----- Mode: EVALUATION (Weights found: bests/Super_class/v7_40_mixed_sgd_controlled/best_model_sgd.pth) -----
#
# ----- Determining Setup for Task A -----
# Using num_classes = 4 (from data_loader import - superclass)
# Using generic superclass names: ['Superclass_0', 'Superclass_1', 'Superclass_2', 'Superclass_3']
# Using device: cuda
#
# ----- Creating DataLoader for Task A -----
# Successfully created DataLoader (test_loader (from create_data_loaders2)).
#
# ----- Instantiating Model Architecture -----
#  Stage 0: Using attention pattern: ('cbam', 'area', 'cbam')
#  Stage 1: Using attention pattern: ('area', 'cbam', 'area')
# ...
